# %% [markdown]
# <a href="https://colab.research.google.com/github/fidelatrstyni/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/KITTEN-1.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# **Jawaban Tugas**

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
img2 = img
img3 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/KITTEN-1.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/KITTEN-1.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='gray')

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/KITTEN-1.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text="Hello",org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **Jawaban Tugas**

# %%
img_act = cv.imread('/content/drive/MyDrive/PCVK/IMG20210128155321.jpg')
img_act1 = cv.cvtColor(img_act,cv.COLOR_BGR2RGB)
plt.imshow(img_act1)

# %%
cv.rectangle(img_act1,pt1=(4000,1500),pt2=(3500,800),color=(0,0,255),thickness=15)
plt.imshow(img_act1)

# %%
cv.circle(img_act1,center=(2700,1000),radius=400,color=(255,0,0),thickness=8)
plt.imshow(img_act1)

# %%
img_soal2 = cv.imread('/content/drive/MyDrive/PCVK/IMG20210128155321.jpg')
img_soall2 = cv.cvtColor(img_soal2,cv.COLOR_BGR2RGB)
plt.imshow(img_soall2)

# %%
cv.rectangle(img_soall2,pt1=(4500,0),pt2=(2500,500),color=(0,0,255),thickness=15)
plt.imshow(img_soall2)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img_soall2,text="Find Where Are You?",org=(2800,300),fontFace=font,fontScale=5,color=(255,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img_soall2)

# %% [markdown]
# Jawaban Pertanyaan
# 1. gambar yang ditampilkan dengan menggunakan matplotlib memvisualisasikan grafik yang terdapat satu sumbu atau lebih, merepresentasikan warna dan glyphs. Sedangkan gambar yang ditampilkan tidak menggunakan matplotlib tidak dapat memvisualisasikan seperti pada gambar yang menggunakan matplotlib
# 2.
# 3. Kode di baris atas menambahkan satu patches karena cv.imshow tidak berjalan di Google Colab maupun Jupyter Notebook. Variabel img merupakan citra asli, sementara grayImg yang sudah dikonversi ke hitam putih (gray).
# 4.
